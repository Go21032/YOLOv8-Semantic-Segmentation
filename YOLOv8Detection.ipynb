# %% [markdown]
# <a href="https://colab.research.google.com/github/Go21032/YOLOv8-Semantic-Segmentation/blob/main/YOLOv8Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.0/793.0 kB 8.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO

# %%
from google.colab import files
uploaded = files.upload()/home/go/slope_ws/src/ros_Golib/slope_edge_detection/scripts/detection_tf.py
# Out:
#      <input type="file" id="files-cd82c3b4-c496-4e37-ae01-6edf9207fb94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd82c3b4-c496-4e37-ae01-6edf9207fb94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip YOLODataset.zip
# Out:
# Archive:  YOLODataset.zip
#    creating: YOLODataset/
#   inflating: YOLODataset/dataset.yaml
#    creating: YOLODataset/images/
#    creating: YOLODataset/images/train/
#   inflating: YOLODataset/images/train/072b4dc7f972cfd40c9c8e38e45f0eef.png
#   inflating: YOLODataset/images/train/089a8efb63c9c1e6ea6a57034dc0766a.png
#   inflating: YOLODataset/images/train/0fbaf86c4847b984807d5f62160f827f.png
#   inflating: YOLODataset/images/train/137be925e194a1453b815c2813136941.png
#   inflating: YOLODataset/images/train/14dcc528f172ab580380cd10d05e4479.png
#   inflating: YOLODataset/images/train/186296be87bfc0a1ca7d76b173bc3895.png
#   inflating: YOLODataset/images/train/19984760b9279c9cc7d487937832d84f.png
#   inflating: YOLODataset/images/train/1d2136ea93cd521181f32e654bcf2b7b.png
#   inflating: YOLODataset/images/train/20a9da97e1c4ad23bac0311964e288ad.png
#   inflating: YOLODataset/images/train/22279adcf321f9d11fafc5763a7726c0.png
# ...

# %%
# !rm YOLODataset.zip

# %%
# !yolo segment train data=/content/YOLODataset/dataset.yaml model=yolov8n-seg.pt epochs=100 imgsz=640 batch=8
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 375MB/s]
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Test
# !yolo segment val model=yolov8n-seg.pt data=/content/YOLODataset/dataset.yaml split=val conf=0.8 iou=0.45
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
# val: Scanning /content/YOLODataset/labels/val.cache... 10 images, 0 backgrounds, 0 corrupt: 100% 10/10 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.80it/s]
#                    all         10         30          0          0          0          0          0          0          0          0
# Speed: 0.3ms preprocess, 23.6ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#予測
# !yolo segment predict model=/content/runs/segment/train/weights/best.pt source=/content/YOLODataset/images/test/IMG_9451.jpg conf=0.8 iou=0.45 save=True
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3258454 parameters, 0 gradients, 12.0 GFLOPs
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/1 /content/YOLODataset/images/test/IMG_9451.jpg: 640x480 1 slope, 2 handrails, 128.9ms
# Speed: 5.3ms preprocess, 128.9ms inference, 974.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/segment/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/runs /content/drive/MyDrive/セマンティックセグメンテーション
